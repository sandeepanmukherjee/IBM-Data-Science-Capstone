# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods City- Cologne

# %% [markdown]
# ### Cologne City New Restaurant Business Recommendation
# **Sandeepan Mukherjee**
#
# ***March 2021***

# %% [markdown]
# <p align="center">
#     <img src="https://i.pinimg.com/736x/4c/86/b6/4c86b6bf23805805110f998604b14f58.jpg" style="width:60%">
# </p>

# %% [markdown]
# ### Table of Content:
# 1. Introduction/Business Understanding
# 2. Analytic approach
# 3. Data requirements
# 4. Data Preparation and pre-processing
# 5. Data Analysis
# 6. Examination of the clusters and Results
# 7. Discussion and Conclusion

# %% [markdown]
# ### 1. Introduction: Business Problem

# %% [markdown]
# Cologne is a city near which the author lives nearby, and it is well-known for its cathedral, trade fairs and conferences, shopping boulevard, and lively party scene. Since it draws a massive amount of visitors, there is a large business potential for restaurants because there is never a lack of people from all over Europe and the world visiting the beautiful region. So ther is wide variety of cousines and restaurants one can chose to start their business venture into.
# Thus, the goal I want to reach with this exercise is to give a simple recommendation to businesses and stakeholders who are looking to open a new restaurant in Cologne and solve issues like in which district of the city will you find a large number or even concentration of which types of restaurants? Where to open a Mediterranean food, German food, or where to get fast food and the list of competitors in that area. The target audience is Food Entrepreneurs and Business owners.

# %% [markdown]
# ### 2. Analytic Approach

# %% [markdown]
# First we are going to analyze the data using exploratory data analysis to uncover the hidden patterns in data and to provide useful insights to the stakeholders.
# And secondly we will use prescriptive analysis to help decide a location to construct new shopping mall using K-means clustering.

# %% [markdown]
# ### 3. Data

# %% [markdown]
# As mentioned in the project requirements, I will use foursquare data about restaurants in Cologne. Foursquare is a US tech company from New York focusing on location data. Their technology and data powers apps such as Apple's Maps, Uber, Twitter and many other household names. Here is an example of a restaurants in Cologne on foursquare: https://de.foursquare.com/v/sattgr%C3%BCn/5c33306cc824ae002c2b414c. I will use foursquare data such as the restaurant name, ID, location and category of food (vegetarian, Italian etc.).
#
# Also, I will use the overview of districts/city parts of Cologne from Wikipedia: https://en.wikipedia.org/wiki/Districts_of_Cologne
#
# Based on this criterion, we will use Data science Python libraries to create a few promising neighborhoods. The benefits of each region can then be specifically articulated so that stakeholders will choose the best possible final spot.

# %% [markdown]
# ### 4. Data Preparation and Pre-processing

# %% [markdown]
# This section we will do data preparation and collection starting with scraping of the Wikipedia page districts of Cologne: https://en.wikipedia.org/wiki/Districts_of_Cologne. To create a pandas dataframe and then perform data cleaning task to make the results look presentable and drop and remove inconsistencies in the dataframe

# %%
#importing required libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
#reading the url in pandas dataframe
df = pd.read_html('https://en.wikipedia.org/wiki/Districts_of_Cologne#Districts')[1]

# %% [markdown]
# #### Remove any Boroughs that are not Assigned

# %%
#Dropping the columns which are not required and contain Nan values
df.drop("Map", axis=1, inplace=True)
df.drop("Coat", axis=1, inplace=True)
df.drop("Town Hall", axis=1, inplace=True)
df["City district"]=df["City district"].str[11:]
df.drop([10], inplace=True)
df.drop([9], inplace=True)
df.head(9)
# Out:
#        City district                                         City parts  \
# 0    Köln-Innenstadt  Altstadt-Nord, Altstadt-Süd, Deutz, Neustadt-N...
# 1  Köln-Rodenkirchen  Bayenthal, Godorf, Hahnwald, Immendorf, Marien...
# 2    Köln-Lindenthal  Braunsfeld, Junkersdorf, Klettenberg, Lindenth...
# 3     Köln-Ehrenfeld  Bickendorf, Bocklemünd/Mengenich, Ehrenfeld, N...
# 4        Köln-Nippes  Bilderstöckchen, Longerich, Mauenheim, Niehl, ...
# 5    Köln-Chorweiler  Blumenberg, Chorweiler, Esch/Auweiler, Fühling...
# 6          Köln-Porz  Eil, Elsdorf, Ensen, Finkenberg, Gremberghoven...
# 7          Köln-Kalk  Brück, Höhenberg, Humboldt/Gremberg, Kalk, Mer...
# 8       Köln-Mülheim  Buchforst, Buchheim, Dellbrück, Dünnwald, Flit...
#
#        Area Population1 Pop. density  \
# 0  16.4 km²     127.033    7.746/km²
# 1  54.6 km²     100.936    1.850/km²
# 2  41.6 km²     137.552    3.308/km²
# 3  23.8 km²     103.621    4.348/km²
# 4  31.8 km²     110.092    3.462/km²
# 5  67.2 km²      80.870    1.204/km²
# 6  78.8 km²     106.520    1.352/km²
# 7  38.2 km²     108.330    2.841/km²
# 8  52.2 km²     144.374    2.764/km²
#
#                                    District Councils
# 0  Bezirksksamt Innenstadt Brückenstraße 19, D-50...
# 1  Bezirksamt Rodenkirchen Hauptstraße 85, D-5099...
# 2  Bezirksamt Lindenthal Aachener Straße 220, 509...
# 3  Bezirksamt Ehrenfeld Venloer Straße 419 – 421,...
# 4   Bezirksamt NippesNeusser Straße 450,D-50733 Köln
# 5  Bezirksamt Chorweiler Pariser Platz 1, D-50765...
# 6  Bezirksamt PorzFriedrich-Ebert-Ufer 64–70, D-5...
# 7  Bezirksamt KalkKalker Hauptstraße 247–273,D-51...
# 8    Bezirksamt Mülheim Wiener Platz 2a,D-51065 Köln

# %% [markdown]
# ### 5. Data Analysis:

# %% [markdown]
# #### Geospatial data from Foursquare
# **In this subsection i used geopy functions do extract neccessary Geospatial Data from Foursquare API where I used the nominatim function to add geospatial data to the data frame, The lat and long is on the right side of the following table**

# %%
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
geolocator = Nominatim(user_agent="Cologne_food")

df['Major_Dist_Coord']= df['City district'].apply(geolocator.geocode).apply(lambda x: (x.latitude, x.longitude))
df[['Latitude', 'Longitude']] = df['Major_Dist_Coord'].apply(pd.Series)

df.drop(['Major_Dist_Coord'], axis=1, inplace=True)
df
# Out:
#        City district                                         City parts  \
# 0    Köln-Innenstadt  Altstadt-Nord, Altstadt-Süd, Deutz, Neustadt-N...
# 1  Köln-Rodenkirchen  Bayenthal, Godorf, Hahnwald, Immendorf, Marien...
# 2    Köln-Lindenthal  Braunsfeld, Junkersdorf, Klettenberg, Lindenth...
# 3     Köln-Ehrenfeld  Bickendorf, Bocklemünd/Mengenich, Ehrenfeld, N...
# 4        Köln-Nippes  Bilderstöckchen, Longerich, Mauenheim, Niehl, ...
# 5    Köln-Chorweiler  Blumenberg, Chorweiler, Esch/Auweiler, Fühling...
# 6          Köln-Porz  Eil, Elsdorf, Ensen, Finkenberg, Gremberghoven...
# 7          Köln-Kalk  Brück, Höhenberg, Humboldt/Gremberg, Kalk, Mer...
# 8       Köln-Mülheim  Buchforst, Buchheim, Dellbrück, Dünnwald, Flit...
#
#        Area Population1 Pop. density  \
# 0  16.4 km²     127.033    7.746/km²
# 1  54.6 km²     100.936    1.850/km²
# 2  41.6 km²     137.552    3.308/km²
# 3  23.8 km²     103.621    4.348/km²
# 4  31.8 km²     110.092    3.462/km²
# 5  67.2 km²      80.870    1.204/km²
# 6  78.8 km²     106.520    1.352/km²
# 7  38.2 km²     108.330    2.841/km²
# 8  52.2 km²     144.374    2.764/km²
#
#                                    District Councils   Latitude  Longitude
# 0  Bezirksksamt Innenstadt Brückenstraße 19, D-50...  50.937328   6.959234
# 1  Bezirksamt Rodenkirchen Hauptstraße 85, D-5099...  50.865622   6.969718
# 2  Bezirksamt Lindenthal Aachener Straße 220, 509...  50.935935   6.871246
# 3  Bezirksamt Ehrenfeld Venloer Straße 419 – 421,...  50.951502   6.916529
# 4   Bezirksamt NippesNeusser Straße 450,D-50733 Köln  50.958994   6.941777
# 5  Bezirksamt Chorweiler Pariser Platz 1, D-50765...  51.021167   6.898034
# 6  Bezirksamt PorzFriedrich-Ebert-Ufer 64–70, D-5...  50.906705   6.999129
# 7  Bezirksamt KalkKalker Hauptstraße 247–273,D-51...  50.931923   7.005806
# 8    Bezirksamt Mülheim Wiener Platz 2a,D-51065 Köln  50.958147   7.013526

# %% [markdown]
# #### Generate a Map of Cologne

# %%
address = 'Cologne'

geolocator = Nominatim(user_agent="cologne_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of cologne are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of cologne are 50.938361, 6.959974.

# %% [markdown]
# #### Importing required libraries for Visualisation and performing Clustering Using Kmeans

# %%
#importing required libraries for Visualisation and performing Clustering Using Kmeans
import json # library to handle JSON files

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
# create map of Cologne using latitude and longitude 
map_cologne = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to the map
for lat, lng, label in zip(df['Latitude'], df['Longitude'], df['City district']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_cologne) 
    
map_cologne
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_d2883ed6e791405387493cf0b80422c9%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d2883ed6e791405387493cf0b80422c9%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_d2883ed6e791405387493cf0b80422c9%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_d2883ed6e791405387493cf0b80422c9%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B50.938361%2C%206.959974%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# #### Explore the Neighbourhoods Using FourSquare

# %%
CLIENT_ID = '4JGSVKZ35LK5D1ONR3QYTHCWNGBY3K1LKJTVEVYEHK3ZHIYO' # your Foursquare ID
CLIENT_SECRET = 'XTT3YE0F4FEDE0DQ423XIYVATRDV2BO4Z112J4TDDGGS2YGW' # your Foursquare Secret
VERSION = '20210220' # what version of Foursquare you want to use
LIMIT = 20 # max limit is 50

# %% [markdown]
# #### Define a Function that Grabs Nearby Venues

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['City district', 
                  'City district Latitude', 
                  'City district Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# #### Get the Venues

# %%
cologne_venues = getNearbyVenues(names=df['City district'],
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude'])
# Out:
# Köln-Innenstadt
# Köln-Rodenkirchen
# Köln-Lindenthal
# Köln-Ehrenfeld
# Köln-Nippes
# Köln-Chorweiler
# Köln-Porz
# Köln-Kalk
# Köln-Mülheim

# %%
print(cologne_venues.shape)
cologne_venues.head()
# Out:
# (113, 7)
#      City district  City district Latitude  City district Longitude  \
# 0  Köln-Innenstadt               50.937328                 6.959234
# 1  Köln-Innenstadt               50.937328                 6.959234
# 2  Köln-Innenstadt               50.937328                 6.959234
# 3  Köln-Innenstadt               50.937328                 6.959234
# 4  Köln-Innenstadt               50.937328                 6.959234
#
#                   Venue  Venue Latitude  Venue Longitude    Venue Category
# 0      Craftbeer Corner       50.937222         6.958928          Beer Bar
# 1            LEGO Store       50.937091         6.956605  Toy / Game Store
# 2  Papa Joe's Jazzlokal       50.937882         6.962241         Jazz Club
# 3           Alter Markt       50.938623         6.960070             Plaza
# 4              Heumarkt       50.936161         6.960461             Plaza

# %% [markdown]
# **In this subsection we will perform some analysis to see the trends, hotspots and choices of food culture of the population in the city.**

# %%
cologne_venues.groupby('City district').count()
# Out:
#                    City district Latitude  City district Longitude  Venue  \
# City district
# Köln-Chorweiler                        12                       12     12
# Köln-Ehrenfeld                         20                       20     20
# Köln-Innenstadt                        20                       20     20
# Köln-Kalk                               4                        4      4
# Köln-Lindenthal                        18                       18     18
# Köln-Mülheim                           20                       20     20
# Köln-Nippes                             9                        9      9
# Köln-Porz                               5                        5      5
# Köln-Rodenkirchen                       5                        5      5
#
#                    Venue Latitude  Venue Longitude  Venue Category
# City district
# Köln-Chorweiler                12               12              12
# Köln-Ehrenfeld                 20               20              20
# Köln-Innenstadt                20               20              20
# Köln-Kalk                       4                4               4
# Köln-Lindenthal                18               18              18
# Köln-Mülheim                   20               20              20
# Köln-Nippes                     9                9               9
# Köln-Porz                       5                5               5
# Köln-Rodenkirchen               5                5               5

# %%
# find out how many unique categories can be curated from all the returned venues
print('There are {} uniques categories.'.format(len(cologne_venues['Venue Category'].unique())))
# Out:
# There are 71 uniques categories.

# %%
# Creating a function return Most Common Venues
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
# one hot encoding
cologne_onehot = pd.get_dummies(cologne_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
cologne_onehot['City district'] = cologne_venues['City district'] 

# move neighborhood column to the first column
fixed_columns = [cologne_onehot.columns[-1]] + list(cologne_onehot.columns[:-1])
cologne_onehot = cologne_onehot[fixed_columns]

cologne_onehot.shape
# Out:
# (113, 72)

# %% [markdown]
# #### Group the rows together and find the frequency of occurance

# %%
cologne_grouped = cologne_onehot.groupby('City district').mean().reset_index()
cologne_grouped
# Out:
#        City district  Art Gallery  Art Museum  Athletics & Sports  \
# 0    Köln-Chorweiler         0.00        0.00            0.000000
# 1     Köln-Ehrenfeld         0.05        0.00            0.000000
# 2    Köln-Innenstadt         0.00        0.05            0.000000
# 3          Köln-Kalk         0.00        0.00            0.000000
# 4    Köln-Lindenthal         0.00        0.00            0.111111
# 5       Köln-Mülheim         0.00        0.00            0.000000
# 6        Köln-Nippes         0.00        0.00            0.000000
# 7          Köln-Porz         0.00        0.00            0.000000
# 8  Köln-Rodenkirchen         0.00        0.00            0.000000
#
#    Auto Garage    Bakery  Bar  Baseball Stadium  Bavarian Restaurant  \
# 0          0.0  0.083333  0.0          0.000000                 0.00
# 1          0.0  0.000000  0.1          0.000000                 0.00
# 2          0.0  0.000000  0.0          0.000000                 0.05
# 3          0.0  0.000000  0.0          0.000000                 0.00
# 4          0.0  0.000000  0.0          0.055556                 0.00
# 5          0.0  0.100000  0.0          0.000000                 0.00
# 6          0.0  0.111111  0.0          0.000000                 0.00
# 7          0.0  0.000000  0.0          0.000000                 0.00
# 8          0.2  0.000000  0.0          0.000000                 0.00
#
#    Beer Bar  ...  Soccer Stadium  Sporting Goods Shop   Stadium  Steakhouse  \
# 0      0.00  ...        0.000000             0.000000  0.000000        0.00
# 1      0.00  ...        0.000000             0.000000  0.000000        0.00
# 2      0.05  ...        0.000000             0.000000  0.000000        0.05
# 3      0.00  ...        0.000000             0.000000  0.000000        0.00
# 4      0.00  ...        0.111111             0.055556  0.055556        0.00
# 5      0.00  ...        0.000000             0.000000  0.000000        0.00
# 6      0.00  ...        0.000000             0.000000  0.000000        0.00
# 7      0.00  ...        0.000000             0.000000  0.000000        0.00
# 8      0.00  ...        0.000000             0.000000  0.000000        0.00
#
#    Supermarket  Theater  Toy / Game Store  Tram Station  Trattoria/Osteria  \
# 0     0.166667     0.00              0.00      0.000000           0.000000
# 1     0.000000     0.00              0.00      0.000000           0.000000
# 2     0.000000     0.00              0.05      0.000000           0.000000
# 3     0.000000     0.25              0.00      0.000000           0.000000
# 4     0.000000     0.00              0.00      0.111111           0.055556
# 5     0.150000     0.00              0.00      0.000000           0.000000
# 6     0.222222     0.00              0.00      0.000000           0.000000
# 7     0.000000     0.00              0.00      0.000000           0.000000
# 8     0.000000     0.00              0.00      0.000000           0.000000
#
#    Vegetarian / Vegan Restaurant
# 0                           0.00
# 1                           0.00
# 2                           0.05
# 3                           0.00
# 4                           0.00
# 5                           0.00
# 6                           0.00
# 7                           0.00
# 8                           0.00
#
# [9 rows x 72 columns]

# %% [markdown]
# **We can use this information to build a dataframe in which you can see the most popular restaurant venue styles for each city district**

# %%
filtered_columns = ['City district'] + [col for col in cologne_grouped.columns if col.endswith('Restaurant')]
dataframe_filtered = cologne_grouped.loc[:, filtered_columns].head()
dataframe_filtered
# Out:
#      City district  Bavarian Restaurant  Chinese Restaurant  Doner Restaurant  \
# 0  Köln-Chorweiler                 0.00                 0.0               0.0
# 1   Köln-Ehrenfeld                 0.00                 0.0               0.0
# 2  Köln-Innenstadt                 0.05                 0.0               0.0
# 3        Köln-Kalk                 0.00                 0.0               0.0
# 4  Köln-Lindenthal                 0.00                 0.0               0.0
#
#    Ethiopian Restaurant  Falafel Restaurant  Fast Food Restaurant  \
# 0                  0.00                0.00              0.083333
# 1                  0.05                0.05              0.000000
# 2                  0.00                0.00              0.050000
# 3                  0.00                0.00              0.000000
# 4                  0.00                0.00              0.000000
#
#    Greek Restaurant  Italian Restaurant  Kebab Restaurant  \
# 0              0.00            0.000000              0.00
# 1              0.00            0.050000              0.05
# 2              0.00            0.000000              0.00
# 3              0.25            0.000000              0.00
# 4              0.00            0.111111              0.00
#
#    Lebanese Restaurant  Restaurant  Scandinavian Restaurant  \
# 0                 0.00         0.0                      0.0
# 1                 0.00         0.1                      0.0
# 2                 0.05         0.0                      0.0
# 3                 0.00         0.0                      0.0
# 4                 0.00         0.0                      0.0
#
#    Vegetarian / Vegan Restaurant
# 0                           0.00
# 1                           0.00
# 2                           0.05
# 3                           0.00
# 4                           0.00

# %% [markdown]
# **Now we will create here a function to retreive top 10 restaurents in city Cologne**

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]
#Retrieving top 10 restaurants
num_top_restaurant = 10
indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['City district']
for ind in np.arange(num_top_restaurant):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['City district'] = dataframe_filtered['City district']

for ind in np.arange(dataframe_filtered.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(dataframe_filtered.iloc[ind, :], num_top_restaurant)

neighborhoods_venues_sorted.head()
# Out:
#      City district          1st Most Common Venue  \
# 0  Köln-Chorweiler           Fast Food Restaurant
# 1   Köln-Ehrenfeld                     Restaurant
# 2  Köln-Innenstadt  Vegetarian / Vegan Restaurant
# 3        Köln-Kalk               Greek Restaurant
# 4  Köln-Lindenthal             Italian Restaurant
#
#            2nd Most Common Venue    3rd Most Common Venue  \
# 0  Vegetarian / Vegan Restaurant  Scandinavian Restaurant
# 1               Kebab Restaurant       Italian Restaurant
# 2            Lebanese Restaurant     Fast Food Restaurant
# 3  Vegetarian / Vegan Restaurant  Scandinavian Restaurant
# 4  Vegetarian / Vegan Restaurant  Scandinavian Restaurant
#
#   4th Most Common Venue    5th Most Common Venue  \
# 0            Restaurant      Lebanese Restaurant
# 1    Falafel Restaurant     Ethiopian Restaurant
# 2   Bavarian Restaurant  Scandinavian Restaurant
# 3            Restaurant      Lebanese Restaurant
# 4            Restaurant      Lebanese Restaurant
#
#            6th Most Common Venue    7th Most Common Venue  \
# 0               Kebab Restaurant       Italian Restaurant
# 1  Vegetarian / Vegan Restaurant  Scandinavian Restaurant
# 2                     Restaurant         Kebab Restaurant
# 3               Kebab Restaurant       Italian Restaurant
# 4               Kebab Restaurant         Greek Restaurant
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0      Greek Restaurant    Falafel Restaurant   Ethiopian Restaurant
# 1   Lebanese Restaurant      Greek Restaurant   Fast Food Restaurant
# 2    Italian Restaurant      Greek Restaurant     Falafel Restaurant
# 3  Fast Food Restaurant    Falafel Restaurant   Ethiopian Restaurant
# 4  Fast Food Restaurant    Falafel Restaurant   Ethiopian Restaurant

# %% [markdown]
# **The table includes the city districts and their most popular venues and Use Kmeans clustering on it create clusters.**

# %%
# set number of clusters
kclusters = 5

cologne_grouped_clustering = dataframe_filtered.drop('City district', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(cologne_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([4, 3, 1, 2, 0], dtype=int32)

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

cologne_merged = df

# merge cologne_merged with cologne_data to add latitude/longitude for each neighborhood
cologne_merged = cologne_merged.join(neighborhoods_venues_sorted.set_index('City district'), on='City district')

cologne_merged.head()
# Out:
#        City district                                         City parts  \
# 0    Köln-Innenstadt  Altstadt-Nord, Altstadt-Süd, Deutz, Neustadt-N...
# 1  Köln-Rodenkirchen  Bayenthal, Godorf, Hahnwald, Immendorf, Marien...
# 2    Köln-Lindenthal  Braunsfeld, Junkersdorf, Klettenberg, Lindenth...
# 3     Köln-Ehrenfeld  Bickendorf, Bocklemünd/Mengenich, Ehrenfeld, N...
# 4        Köln-Nippes  Bilderstöckchen, Longerich, Mauenheim, Niehl, ...
#
#        Area Population1 Pop. density  \
# 0  16.4 km²     127.033    7.746/km²
# 1  54.6 km²     100.936    1.850/km²
# 2  41.6 km²     137.552    3.308/km²
# 3  23.8 km²     103.621    4.348/km²
# 4  31.8 km²     110.092    3.462/km²
#
#                                    District Councils   Latitude  Longitude  \
# 0  Bezirksksamt Innenstadt Brückenstraße 19, D-50...  50.937328   6.959234
# 1  Bezirksamt Rodenkirchen Hauptstraße 85, D-5099...  50.865622   6.969718
# 2  Bezirksamt Lindenthal Aachener Straße 220, 509...  50.935935   6.871246
# 3  Bezirksamt Ehrenfeld Venloer Straße 419 – 421,...  50.951502   6.916529
# 4   Bezirksamt NippesNeusser Straße 450,D-50733 Köln  50.958994   6.941777
#
#    Cluster Labels          1st Most Common Venue  \
# 0             1.0  Vegetarian / Vegan Restaurant
# 1             NaN                            NaN
# 2             0.0             Italian Restaurant
# 3             3.0                     Restaurant
# 4             NaN                            NaN
#
#            2nd Most Common Venue    3rd Most Common Venue  \
# 0            Lebanese Restaurant     Fast Food Restaurant
# 1                            NaN                      NaN
# 2  Vegetarian / Vegan Restaurant  Scandinavian Restaurant
# 3               Kebab Restaurant       Italian Restaurant
# 4                            NaN                      NaN
#
#   4th Most Common Venue    5th Most Common Venue  \
# 0   Bavarian Restaurant  Scandinavian Restaurant
# 1                   NaN                      NaN
# 2            Restaurant      Lebanese Restaurant
# 3    Falafel Restaurant     Ethiopian Restaurant
# 4                   NaN                      NaN
#
#            6th Most Common Venue    7th Most Common Venue  \
# 0                     Restaurant         Kebab Restaurant
# 1                            NaN                      NaN
# 2               Kebab Restaurant         Greek Restaurant
# 3  Vegetarian / Vegan Restaurant  Scandinavian Restaurant
# 4                            NaN                      NaN
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0    Italian Restaurant      Greek Restaurant     Falafel Restaurant
# 1                   NaN                   NaN                    NaN
# 2  Fast Food Restaurant    Falafel Restaurant   Ethiopian Restaurant
# 3   Lebanese Restaurant      Greek Restaurant   Fast Food Restaurant
# 4                   NaN                   NaN                    NaN

# %%
#Dropping Null Values
cologne_merged.dropna()
# Out:
#      City district                                         City parts  \
# 0  Köln-Innenstadt  Altstadt-Nord, Altstadt-Süd, Deutz, Neustadt-N...
# 2  Köln-Lindenthal  Braunsfeld, Junkersdorf, Klettenberg, Lindenth...
# 3   Köln-Ehrenfeld  Bickendorf, Bocklemünd/Mengenich, Ehrenfeld, N...
# 5  Köln-Chorweiler  Blumenberg, Chorweiler, Esch/Auweiler, Fühling...
# 7        Köln-Kalk  Brück, Höhenberg, Humboldt/Gremberg, Kalk, Mer...
#
#        Area Population1 Pop. density  \
# 0  16.4 km²     127.033    7.746/km²
# 2  41.6 km²     137.552    3.308/km²
# 3  23.8 km²     103.621    4.348/km²
# 5  67.2 km²      80.870    1.204/km²
# 7  38.2 km²     108.330    2.841/km²
#
#                                    District Councils   Latitude  Longitude  \
# 0  Bezirksksamt Innenstadt Brückenstraße 19, D-50...  50.937328   6.959234
# 2  Bezirksamt Lindenthal Aachener Straße 220, 509...  50.935935   6.871246
# 3  Bezirksamt Ehrenfeld Venloer Straße 419 – 421,...  50.951502   6.916529
# 5  Bezirksamt Chorweiler Pariser Platz 1, D-50765...  51.021167   6.898034
# 7  Bezirksamt KalkKalker Hauptstraße 247–273,D-51...  50.931923   7.005806
#
#    Cluster Labels          1st Most Common Venue  \
# 0             1.0  Vegetarian / Vegan Restaurant
# 2             0.0             Italian Restaurant
# 3             3.0                     Restaurant
# 5             4.0           Fast Food Restaurant
# 7             2.0               Greek Restaurant
#
#            2nd Most Common Venue    3rd Most Common Venue  \
# 0            Lebanese Restaurant     Fast Food Restaurant
# 2  Vegetarian / Vegan Restaurant  Scandinavian Restaurant
# 3               Kebab Restaurant       Italian Restaurant
# 5  Vegetarian / Vegan Restaurant  Scandinavian Restaurant
# 7  Vegetarian / Vegan Restaurant  Scandinavian Restaurant
#
#   4th Most Common Venue    5th Most Common Venue  \
# 0   Bavarian Restaurant  Scandinavian Restaurant
# 2            Restaurant      Lebanese Restaurant
# 3    Falafel Restaurant     Ethiopian Restaurant
# 5            Restaurant      Lebanese Restaurant
# 7            Restaurant      Lebanese Restaurant
#
#            6th Most Common Venue    7th Most Common Venue  \
# 0                     Restaurant         Kebab Restaurant
# 2               Kebab Restaurant         Greek Restaurant
# 3  Vegetarian / Vegan Restaurant  Scandinavian Restaurant
# 5               Kebab Restaurant       Italian Restaurant
# 7               Kebab Restaurant       Italian Restaurant
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0    Italian Restaurant      Greek Restaurant     Falafel Restaurant
# 2  Fast Food Restaurant    Falafel Restaurant   Ethiopian Restaurant
# 3   Lebanese Restaurant      Greek Restaurant   Fast Food Restaurant
# 5      Greek Restaurant    Falafel Restaurant   Ethiopian Restaurant
# 7  Fast Food Restaurant    Falafel Restaurant   Ethiopian Restaurant

# %% [markdown]
# **The table includes the city districts and their most popular venues, which have now been allocated one of five distinct cluster labels ranging from 0 to 4.**
#
# **We can now use the cluster labels to show the city districts marked with a cluster-specific color on a map using the library folium:**

# %%
address = 'Köln Innenstadt'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of cologne are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of cologne are 50.93732845, 6.959234323073302.

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, Citydistrict, ClusterLabels in zip(cologne_merged['Latitude'], cologne_merged['Longitude'], cologne_merged['City district'], cologne_merged['Cluster Labels']):
    label = folium.Popup(str(Citydistrict) + ' Cluster ' + str(ClusterLabels), parse_html=True)
    #label = '{}, {}'.format(Citydistrict, ClusterLabels)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        #color=rainbow[Cluster-1],
        fill=True,
        #fill_color=rainbow[Cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f92244bf209646d2ad8dd109c41fbf10%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f92244bf209646d2ad8dd109c41fbf10%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f92244bf209646d2ad8dd109c41fbf10%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_f92244bf209646d2ad8dd109c41fbf10%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B50.93732845%2C%206.959234323073302%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# #### What you see above is the nine bubbles for the nine city districts, with five different colors for the five different clusters.

# %% [markdown]
# ### 6. Examination of the clusters and Results

# %% [markdown]
# **Now, we will examine each cluster and determine the discriminating venue categories that distinguish each cluster. This will help our stakeholders understand in which area of the city there is a more footfall of customers and their cousine choice**

# %% [markdown]
# #### *Cluster 1*
# **Italian Cuisine Cluster(Lindenthal)**

# %%
cologne_merged.loc[cologne_merged['Cluster Labels'] == 0, cologne_merged.columns[[1] + list(range(5, cologne_merged.shape[1]))]]
# Out:
#                                           City parts  \
# 2  Braunsfeld, Junkersdorf, Klettenberg, Lindenth...
#
#                                    District Councils   Latitude  Longitude  \
# 2  Bezirksamt Lindenthal Aachener Straße 220, 509...  50.935935   6.871246
#
#    Cluster Labels 1st Most Common Venue          2nd Most Common Venue  \
# 2             0.0    Italian Restaurant  Vegetarian / Vegan Restaurant
#
#      3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 2  Scandinavian Restaurant            Restaurant   Lebanese Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 2      Kebab Restaurant      Greek Restaurant  Fast Food Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 2    Falafel Restaurant   Ethiopian Restaurant

# %% [markdown]
# #### *Cluster 2*
# **Vegan Cluster(Innenstadt)**

# %%
cologne_merged.loc[cologne_merged['Cluster Labels'] == 1, cologne_merged.columns[[1] + list(range(5, cologne_merged.shape[1]))]]
# Out:
#                                           City parts  \
# 0  Altstadt-Nord, Altstadt-Süd, Deutz, Neustadt-N...
#
#                                    District Councils   Latitude  Longitude  \
# 0  Bezirksksamt Innenstadt Brückenstraße 19, D-50...  50.937328   6.959234
#
#    Cluster Labels          1st Most Common Venue 2nd Most Common Venue  \
# 0             1.0  Vegetarian / Vegan Restaurant   Lebanese Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue    5th Most Common Venue  \
# 0  Fast Food Restaurant   Bavarian Restaurant  Scandinavian Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0            Restaurant      Kebab Restaurant    Italian Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 0      Greek Restaurant     Falafel Restaurant

# %% [markdown]
# #### *Cluster 3*
# **Greek Cuisine Cluster(KalkKalker)**

# %%
cologne_merged.loc[cologne_merged['Cluster Labels'] == 2, cologne_merged.columns[[1] + list(range(5, cologne_merged.shape[1]))]]
# Out:
#                                           City parts  \
# 7  Brück, Höhenberg, Humboldt/Gremberg, Kalk, Mer...
#
#                                    District Councils   Latitude  Longitude  \
# 7  Bezirksamt KalkKalker Hauptstraße 247–273,D-51...  50.931923   7.005806
#
#    Cluster Labels 1st Most Common Venue          2nd Most Common Venue  \
# 7             2.0      Greek Restaurant  Vegetarian / Vegan Restaurant
#
#      3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 7  Scandinavian Restaurant            Restaurant   Lebanese Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 7      Kebab Restaurant    Italian Restaurant  Fast Food Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 7    Falafel Restaurant   Ethiopian Restaurant

# %% [markdown]
# #### *Cluster 4*
# **Turkish Cuisine Cluster(Ehrenfeld)**

# %%
cologne_merged.loc[cologne_merged['Cluster Labels'] == 3, cologne_merged.columns[[1] + list(range(5, cologne_merged.shape[1]))]]
# Out:
#                                           City parts  \
# 3  Bickendorf, Bocklemünd/Mengenich, Ehrenfeld, N...
#
#                                    District Councils   Latitude  Longitude  \
# 3  Bezirksamt Ehrenfeld Venloer Straße 419 – 421,...  50.951502   6.916529
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 3             3.0            Restaurant      Kebab Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 3    Italian Restaurant    Falafel Restaurant  Ethiopian Restaurant
#
#            6th Most Common Venue    7th Most Common Venue  \
# 3  Vegetarian / Vegan Restaurant  Scandinavian Restaurant
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 3   Lebanese Restaurant      Greek Restaurant   Fast Food Restaurant

# %% [markdown]
# #### *Cluster 5*
# **Thai Cuisine Cluster(Chorweiler)**

# %%
cologne_merged.loc[cologne_merged['Cluster Labels'] == 4, cologne_merged.columns[[1] + list(range(5, cologne_merged.shape[1]))]]
# Out:
#                                           City parts  \
# 5  Blumenberg, Chorweiler, Esch/Auweiler, Fühling...
#
#                                    District Councils   Latitude  Longitude  \
# 5  Bezirksamt Chorweiler Pariser Platz 1, D-50765...  51.021167   6.898034
#
#    Cluster Labels 1st Most Common Venue          2nd Most Common Venue  \
# 5             4.0  Fast Food Restaurant  Vegetarian / Vegan Restaurant
#
#      3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 5  Scandinavian Restaurant            Restaurant   Lebanese Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 5      Kebab Restaurant    Italian Restaurant      Greek Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 5    Falafel Restaurant   Ethiopian Restaurant

# %% [markdown]
# ### 7. Discussion and Conclusion

# %% [markdown]
# The aim of this project was to find Cologne areas near the center with a low number of restaurants in order to assist stakeholders in narrowing their quest for an optimal location for a new restaurant.
# We defined analysis (köln Innenstadt) and then created an extensive set of locations that satisfy some specific requirements about existing nearby restaurants by measuring restaurant density distribution from Foursquare data.
# Clustering of those areas was then conducted in order to establish major zones of interest, and addresses for those zone centers were generated to be used as starting points for stakeholders' final discovery.
# Answer to Business Question:
#     **Cluster 1** is relects that most preffered place where customers prefer Italian Cuisine but opening an Italian Restaurant In cluster 1 would also lead to sheer level of high competition. Whereas Cluster 2,3 and 5 have less footfall for Italian Cuisine but there is a huge business opportunity for good Italian Cuisine Restaurant.
#     **Cluster 2** reflects that Vegetarian/Vegan Restaurant is most preffered by customers and visitors there and opening Vegan Cuisine restaurant in this cluster would lead to lot of competition but Cluster 4 would be the best place for stakeholders and business owners to open a good Vegan cuisine restaurant
#     **Cluster 3** reflects that Greek Restaurant is most preffered by customers and visitors there and opening Greek Cuisine restaurant in this cluster would lead to lot of competition but Cluster 2 would be the best place for stakeholders and business owners to open a good Vegan cuisine restaurant and Cluster 1,4 and 5 also looks to be a good place as well.
#     **Cluster 4** reflects that Turkish Restaurant is most preffered by customers and visitors there and opening Turkish Cuisine restaurant in this cluster would lead to lot of competition but Cluster 2 would be the best place for stakeholders and business owners to open a good Turkish cuisine restaurant and Cluster 1, 3 and 5 also looks to be a good place as well.
#     **Cluster 5** reflects that Thai Restaurant is most preffered by customers and visitors there and opening Thai Cuisine restaurant in this cluster would lead to lot of competition but Cluster 4 would be the best place for stakeholders and business owners to open a good Turkish cuisine restaurant.
#
# Stakeholders will make the final decision on optimal restaurant position based on unique characteristics of communities and areas in each recommended district, taking into account additional factors such as attractiveness of each location, levels of noise / proximity to major connection roads, real estate, costs, social and economic complexities of each neighborhood.
